# %% [markdown]
# # Move class into separate species folder

# %%
import pandas as pd
import os
import shutil

# %%
species_directory = '/users/PAS2186/balasubramaniam29/new/Split_dataset'
det_directory = '/users/PAS2186/balasubramaniam29/new/final_Mar 25/Individual species classifier/dataset'
csv_file_path = 'all_species_info.csv'
df = pd.read_csv(csv_file_path)

for split in os.listdir(species_directory):
    split_path = os.path.join(species_directory, split)
    
    if os.path.isdir(split_path):
        for order in os.listdir(split_path):
            if order in ["Amphibia", "Aves", "Serpentes", "Mammalia"]:
                order_path = os.path.join(split_path, order)

                if os.path.isdir(order_path):
                    for files in os.listdir(order_path):
                        files_path = os.path.join(order_path, files)
                        species_info = df[df['Image Name'] == files]

                        if not species_info.empty:
                            species_name = species_info['Species Name'].values[0]
                            output = os.path.join(det_directory, order, split, species_name)
                            class_path = os.path.join(order_path, species_name)
                            os.makedirs(output, exist_ok=True)

                            destination_image = os.path.join(output, files)
                            shutil.copy(files_path, destination_image)

# %% [markdown]
# # Remove some images from Easter Garter Snake

# %%
import os
import random
import shutil

def create_subset(source_dir, dest_dir, num_images):
    # Create the destination directory if it doesn't exist
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)

    # List all files in the source directory
    all_images = os.listdir(source_dir)

    # Randomly select num_images from the list
    selected_images = random.sample(all_images, num_images)

    # Move selected images to the destination directory
    for image in selected_images:
        source_path = os.path.join(source_dir, image)
        dest_path = os.path.join(dest_dir, image)
        shutil.copy(source_path, dest_path)

if __name__ == "__main__":
    # Specify the source directory, destination directory, and the number of images
    source_directory = "/users/PAS2186/balasubramaniam29/new/final_Mar 25/Individual species classifier/dataset/Serpentes/val/Eastern"
    destination_directory = "/users/PAS2186/balasubramaniam29/new/final_Mar 25/Individual species classifier/dataset/Serpentes/val/Eastern Gartersnake"
    num_images_to_select = 100

    # Call the function to create the subset
    create_subset(source_directory, destination_directory, num_images_to_select)

# %% [markdown]
# ## Split the input dataset into subfolders

# %%
import splitfolders

# %%
#Species level
input_folder = '/users/PAS2186/balasubramaniam29/Latest species classifier backup/Sorted_by_species/Serpentes'
splitfolders.ratio(input_folder, 
                           output="/users/PAS2186/balasubramaniam29/new/Individual training/splitimages/Serpentes", 
                           seed=42, 
                           ratio=(.7, .2, .1),
                           group_prefix=None,
                           move=False
                          )
# Out:
# Copying files: 36116 files [14:56, 40.29 files/s]

# %% [markdown]
# ## Import necessary packages

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from collections import OrderedDict

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
#import tensorflow.keras
from PIL import Image, ImageOps
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import os
# Out:
# 2024-03-27 10:18:51.947229: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-27 10:18:53.127136: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-27 10:18:53.326406: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-03-27 10:18:53.326433: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-03-27 10:18:56.918015: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-03-27 10:18:56.918702: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-03-27 10:18:56.918721: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
image_size = 224
batch_size = 64

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %% [markdown]
# # Create image generator

# %%
base_dir = '/users/PAS2186/balasubramaniam29/new/final_Mar 25/Individual species classifier/dataset/Mammalia/'
train_dir = base_dir+ 'train/'
val_dir = base_dir + 'val/'
testing_dir = base_dir + '/test/'
input_shape = (image_size, image_size, 3)

# %%
train_datagen = ImageDataGenerator(rescale=1. / 255,
                              height_shift_range= 0.02,
                              width_shift_range=0.02,
                              rotation_range=-0.1,
                              shear_range = 0.01,
                              fill_mode='nearest',
                              zoom_range=0.3,
                              brightness_range=(0.5, 1.5))

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(image_size, image_size),
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 29169 images belonging to 16 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1. / 255)

test_generator = test_datagen.flow_from_directory(
    val_dir,
    target_size=(image_size, image_size),
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 3884 images belonging to 16 classes.

# %%
testing_datagen = ImageDataGenerator(rescale=1. / 255)

testing_generator = testing_datagen.flow_from_directory(
    testing_dir,
    target_size=(image_size, image_size),
    batch_size=batch_size,
    shuffle=False,
    class_mode='categorical')
# Out:
# Found 5847 images belonging to 16 classes.

# %%
cls_train = test_generator.classes
from collections import OrderedDict
classes = list(train_generator.class_indices.keys())

num_values = []
unique, counts = np.unique(cls_train, return_counts=True)
valdict=OrderedDict(zip(unique, counts))
#print(unique, counts)
class_num = len(classes)
for i in range(class_num):
    if i not in valdict:
        valdict[i] = 0
    num_values.append(valdict[i])
plt.figure(figsize=(50,10))
x = np.arange(len(num_values))
xlabel = classes
plt.bar(x, num_values)
plt.xticks(x, xlabel)
plt.show()
print(xlabel, num_values)
# Out:
# ['American Mink', 'Brown Rat', 'Eastern Chipmunk', 'Eastern Cottontail', 'Long-tailed Weasel', 'Masked Shrew', 'Meadow Jumping Mouse', 'Meadow Vole', 'N. Short-tailed Shrew', 'Raccoon', 'Star-nosed mole', 'Striped Skunk', 'Virginia Opossum', 'White-footed Mouse', 'Woodchuck', 'Woodland Jumping Mouse'] [42, 1, 19, 326, 232, 424, 16, 1416, 74, 6, 11, 10, 98, 1054, 4, 151]

# %%
# Assuming you have the class labels and indices
classes = list(train_generator.class_indices.keys())

# Get class counts for the train set
cls_train = train_generator.classes
unique_train, counts_train = np.unique(cls_train, return_counts=True)
train_dict = OrderedDict(zip(unique_train, counts_train))

# Get class counts for the test set
cls_test = testing_generator.classes
unique_test, counts_test = np.unique(cls_test, return_counts=True)
test_dict = OrderedDict(zip(unique_test, counts_test))

# Get class counts for the validation set
cls_val = test_generator.classes
unique_val, counts_val = np.unique(cls_val, return_counts=True)
val_dict = OrderedDict(zip(unique_val, counts_val))

for i in range(len(classes)):
    label = classes[i]
    if i not in train_dict:
        train_dict[i] = 0
    if i not in test_dict:
        test_dict[i] = 0
    if i not in val_dict:
        val_dict[i] = 0
        
# Create a table with the counts for each class
table_data = {'Class': classes, 'Train': [], 'Test': [], 'Validation': []}

for label in classes:
    table_data['Train'].append(train_dict[train_generator.class_indices[label]])
    table_data['Test'].append(test_dict[test_generator.class_indices[label]])
    table_data['Validation'].append(val_dict[testing_generator.class_indices[label]])

# Display the table
import pandas as pd
df = pd.DataFrame(table_data)
print(df)
# Out:
#                      Class  Train  Test  Validation
# 0            American Mink    318    65          42
# 1                Brown Rat      6     1           1
# 2         Eastern Chipmunk    148    31          19
# 3       Eastern Cottontail   2447   490         326
# 4       Long-tailed Weasel   1743   350         232
# 5             Masked Shrew   3181   637         424
# 6     Meadow Jumping Mouse    120    24          16
# 7              Meadow Vole  10626  2127        1416
# 8    N. Short-tailed Shrew    559   113          74
# 9                  Raccoon     46    10           6
# 10         Star-nosed mole     83    17          11
# 11           Striped Skunk     78    16          10
# 12        Virginia Opossum    738   149          98
# 13      White-footed Mouse   7911  1583        1054
# 14               Woodchuck     33     7           4
# 15  Woodland Jumping Mouse   1132   227         151

# %% [markdown]
# ## Download MobileNetV2 model

# %%
pretrained_model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False)
pretrained_model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# 2024-03-27 10:25:15.179552: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-03-27 10:25:15.180707: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2024-03-27 10:25:15.181435: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2024-03-27 10:25:15.182081: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2024-03-27 10:25:15.182755: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2024-03-27 10:25:15.183419: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2024-03-27 10:25:15.184029: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2024-03-27 10:25:15.184689: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2024-03-27 10:25:15.184721: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2024-03-27 10:25:15.185376: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  Conv1 (Conv2D)                 (None, None, None,   864         ['input_1[0][0]']
#                                 32)
#
#  bn_Conv1 (BatchNormalization)  (None, None, None,   128         ['Conv1[0][0]']
#                                 32)
#
#  Conv1_relu (ReLU)              (None, None, None,   0           ['bn_Conv1[0][0]']
#                                 32)
#
#  expanded_conv_depthwise (Depth  (None, None, None,   288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    32)
#
#  expanded_conv_depthwise_BN (Ba  (None, None, None,   128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              32)
#
#  expanded_conv_depthwise_relu (  (None, None, None,   0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          32)                              ]']
#
#  expanded_conv_project (Conv2D)  (None, None, None,   512        ['expanded_conv_depthwise_relu[0]
#                                 16)                              [0]']
#
#  expanded_conv_project_BN (Batc  (None, None, None,   64         ['expanded_conv_project[0][0]']
#  hNormalization)                16)
#
#  block_1_expand (Conv2D)        (None, None, None,   1536        ['expanded_conv_project_BN[0][0]'
#                                 96)                              ]
#
#  block_1_expand_BN (BatchNormal  (None, None, None,   384        ['block_1_expand[0][0]']
#  ization)                       96)
#
#  block_1_expand_relu (ReLU)     (None, None, None,   0           ['block_1_expand_BN[0][0]']
#                                 96)
#
#  block_1_pad (ZeroPadding2D)    (None, None, None,   0           ['block_1_expand_relu[0][0]']
#                                 96)
#
#  block_1_depthwise (DepthwiseCo  (None, None, None,   864        ['block_1_pad[0][0]']
#  nv2D)                          96)
#
#  block_1_depthwise_BN (BatchNor  (None, None, None,   384        ['block_1_depthwise[0][0]']
#  malization)                    96)
#
#  block_1_depthwise_relu (ReLU)  (None, None, None,   0           ['block_1_depthwise_BN[0][0]']
#                                 96)
#
#  block_1_project (Conv2D)       (None, None, None,   2304        ['block_1_depthwise_relu[0][0]']
#                                 24)
#
#  block_1_project_BN (BatchNorma  (None, None, None,   96         ['block_1_project[0][0]']
#  lization)                      24)
#
#  block_2_expand (Conv2D)        (None, None, None,   3456        ['block_1_project_BN[0][0]']
#                                 144)
#
#  block_2_expand_BN (BatchNormal  (None, None, None,   576        ['block_2_expand[0][0]']
#  ization)                       144)
#
#  block_2_expand_relu (ReLU)     (None, None, None,   0           ['block_2_expand_BN[0][0]']
#                                 144)
#
#  block_2_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_2_expand_relu[0][0]']
#  nv2D)                          144)
#
#  block_2_depthwise_BN (BatchNor  (None, None, None,   576        ['block_2_depthwise[0][0]']
#  malization)                    144)
#
#  block_2_depthwise_relu (ReLU)  (None, None, None,   0           ['block_2_depthwise_BN[0][0]']
#                                 144)
#
#  block_2_project (Conv2D)       (None, None, None,   3456        ['block_2_depthwise_relu[0][0]']
#                                 24)
#
#  block_2_project_BN (BatchNorma  (None, None, None,   96         ['block_2_project[0][0]']
#  lization)                      24)
#
#  block_2_add (Add)              (None, None, None,   0           ['block_1_project_BN[0][0]',
#                                 24)                               'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, None, None,   3456        ['block_2_add[0][0]']
#                                 144)
#
#  block_3_expand_BN (BatchNormal  (None, None, None,   576        ['block_3_expand[0][0]']
#  ization)                       144)
#
#  block_3_expand_relu (ReLU)     (None, None, None,   0           ['block_3_expand_BN[0][0]']
#                                 144)
#
#  block_3_pad (ZeroPadding2D)    (None, None, None,   0           ['block_3_expand_relu[0][0]']
#                                 144)
#
#  block_3_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_3_pad[0][0]']
#  nv2D)                          144)
#
#  block_3_depthwise_BN (BatchNor  (None, None, None,   576        ['block_3_depthwise[0][0]']
#  malization)                    144)
#
#  block_3_depthwise_relu (ReLU)  (None, None, None,   0           ['block_3_depthwise_BN[0][0]']
#                                 144)
#
#  block_3_project (Conv2D)       (None, None, None,   4608        ['block_3_depthwise_relu[0][0]']
#                                 32)
#
#  block_3_project_BN (BatchNorma  (None, None, None,   128        ['block_3_project[0][0]']
#  lization)                      32)
#
#  block_4_expand (Conv2D)        (None, None, None,   6144        ['block_3_project_BN[0][0]']
#                                 192)
#
#  block_4_expand_BN (BatchNormal  (None, None, None,   768        ['block_4_expand[0][0]']
#  ization)                       192)
#
#  block_4_expand_relu (ReLU)     (None, None, None,   0           ['block_4_expand_BN[0][0]']
#                                 192)
#
#  block_4_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_4_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_4_depthwise_BN (BatchNor  (None, None, None,   768        ['block_4_depthwise[0][0]']
#  malization)                    192)
#
#  block_4_depthwise_relu (ReLU)  (None, None, None,   0           ['block_4_depthwise_BN[0][0]']
#                                 192)
#
#  block_4_project (Conv2D)       (None, None, None,   6144        ['block_4_depthwise_relu[0][0]']
#                                 32)
#
#  block_4_project_BN (BatchNorma  (None, None, None,   128        ['block_4_project[0][0]']
#  lization)                      32)
#
#  block_4_add (Add)              (None, None, None,   0           ['block_3_project_BN[0][0]',
#                                 32)                               'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, None, None,   6144        ['block_4_add[0][0]']
#                                 192)
#
#  block_5_expand_BN (BatchNormal  (None, None, None,   768        ['block_5_expand[0][0]']
#  ization)                       192)
#
#  block_5_expand_relu (ReLU)     (None, None, None,   0           ['block_5_expand_BN[0][0]']
#                                 192)
#
#  block_5_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_5_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_5_depthwise_BN (BatchNor  (None, None, None,   768        ['block_5_depthwise[0][0]']
#  malization)                    192)
#
#  block_5_depthwise_relu (ReLU)  (None, None, None,   0           ['block_5_depthwise_BN[0][0]']
#                                 192)
#
#  block_5_project (Conv2D)       (None, None, None,   6144        ['block_5_depthwise_relu[0][0]']
#                                 32)
#
#  block_5_project_BN (BatchNorma  (None, None, None,   128        ['block_5_project[0][0]']
#  lization)                      32)
#
#  block_5_add (Add)              (None, None, None,   0           ['block_4_add[0][0]',
#                                 32)                               'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, None, None,   6144        ['block_5_add[0][0]']
#                                 192)
#
#  block_6_expand_BN (BatchNormal  (None, None, None,   768        ['block_6_expand[0][0]']
#  ization)                       192)
#
#  block_6_expand_relu (ReLU)     (None, None, None,   0           ['block_6_expand_BN[0][0]']
#                                 192)
#
#  block_6_pad (ZeroPadding2D)    (None, None, None,   0           ['block_6_expand_relu[0][0]']
#                                 192)
#
#  block_6_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_6_pad[0][0]']
#  nv2D)                          192)
#
#  block_6_depthwise_BN (BatchNor  (None, None, None,   768        ['block_6_depthwise[0][0]']
#  malization)                    192)
#
#  block_6_depthwise_relu (ReLU)  (None, None, None,   0           ['block_6_depthwise_BN[0][0]']
#                                 192)
#
#  block_6_project (Conv2D)       (None, None, None,   12288       ['block_6_depthwise_relu[0][0]']
#                                 64)
#
#  block_6_project_BN (BatchNorma  (None, None, None,   256        ['block_6_project[0][0]']
#  lization)                      64)
#
#  block_7_expand (Conv2D)        (None, None, None,   24576       ['block_6_project_BN[0][0]']
#                                 384)
#
#  block_7_expand_BN (BatchNormal  (None, None, None,   1536       ['block_7_expand[0][0]']
#  ization)                       384)
#
#  block_7_expand_relu (ReLU)     (None, None, None,   0           ['block_7_expand_BN[0][0]']
#                                 384)
#
#  block_7_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_7_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_7_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_7_depthwise[0][0]']
#  malization)                    384)
#
#  block_7_depthwise_relu (ReLU)  (None, None, None,   0           ['block_7_depthwise_BN[0][0]']
#                                 384)
#
#  block_7_project (Conv2D)       (None, None, None,   24576       ['block_7_depthwise_relu[0][0]']
#                                 64)
#
#  block_7_project_BN (BatchNorma  (None, None, None,   256        ['block_7_project[0][0]']
#  lization)                      64)
#
#  block_7_add (Add)              (None, None, None,   0           ['block_6_project_BN[0][0]',
#                                 64)                               'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, None, None,   24576       ['block_7_add[0][0]']
#                                 384)
#
#  block_8_expand_BN (BatchNormal  (None, None, None,   1536       ['block_8_expand[0][0]']
#  ization)                       384)
#
#  block_8_expand_relu (ReLU)     (None, None, None,   0           ['block_8_expand_BN[0][0]']
#                                 384)
#
#  block_8_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_8_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_8_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_8_depthwise[0][0]']
#  malization)                    384)
#
#  block_8_depthwise_relu (ReLU)  (None, None, None,   0           ['block_8_depthwise_BN[0][0]']
#                                 384)
#
#  block_8_project (Conv2D)       (None, None, None,   24576       ['block_8_depthwise_relu[0][0]']
#                                 64)
#
#  block_8_project_BN (BatchNorma  (None, None, None,   256        ['block_8_project[0][0]']
#  lization)                      64)
#
#  block_8_add (Add)              (None, None, None,   0           ['block_7_add[0][0]',
#                                 64)                               'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, None, None,   24576       ['block_8_add[0][0]']
#                                 384)
#  block_9_expand_BN (BatchNormal  (None, None, None,   1536       ['block_9_expand[0][0]']
#  ization)                       384)
#
#  block_9_expand_relu (ReLU)     (None, None, None,   0           ['block_9_expand_BN[0][0]']
#                                 384)
#
#  block_9_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_9_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_9_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_9_depthwise[0][0]']
#  malization)                    384)
#
#  block_9_depthwise_relu (ReLU)  (None, None, None,   0           ['block_9_depthwise_BN[0][0]']
#                                 384)
#
#  block_9_project (Conv2D)       (None, None, None,   24576       ['block_9_depthwise_relu[0][0]']
#                                 64)
#
#  block_9_project_BN (BatchNorma  (None, None, None,   256        ['block_9_project[0][0]']
#  lization)                      64)
#
#  block_9_add (Add)              (None, None, None,   0           ['block_8_add[0][0]',
#                                 64)                               'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, None, None,   24576       ['block_9_add[0][0]']
#                                 384)
#
#  block_10_expand_BN (BatchNorma  (None, None, None,   1536       ['block_10_expand[0][0]']
#  lization)                      384)
#
#  block_10_expand_relu (ReLU)    (None, None, None,   0           ['block_10_expand_BN[0][0]']
#                                 384)
#
#  block_10_depthwise (DepthwiseC  (None, None, None,   3456       ['block_10_expand_relu[0][0]']
#  onv2D)                         384)
#
#  block_10_depthwise_BN (BatchNo  (None, None, None,   1536       ['block_10_depthwise[0][0]']
#  rmalization)                   384)
#
#  block_10_depthwise_relu (ReLU)  (None, None, None,   0          ['block_10_depthwise_BN[0][0]']
#                                 384)
#
#  block_10_project (Conv2D)      (None, None, None,   36864       ['block_10_depthwise_relu[0][0]']
#                                 96)
#
#  block_10_project_BN (BatchNorm  (None, None, None,   384        ['block_10_project[0][0]']
#  alization)                     96)
#
#  block_11_expand (Conv2D)       (None, None, None,   55296       ['block_10_project_BN[0][0]']
#                                 576)
#
#  block_11_expand_BN (BatchNorma  (None, None, None,   2304       ['block_11_expand[0][0]']
#  lization)                      576)
#
#  block_11_expand_relu (ReLU)    (None, None, None,   0           ['block_11_expand_BN[0][0]']
#                                 576)
#
#  block_11_depthwise (DepthwiseC  (None, None, None,   5184       ['block_11_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_11_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_11_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_11_depthwise_relu (ReLU)  (None, None, None,   0          ['block_11_depthwise_BN[0][0]']
#                                 576)
#
#  block_11_project (Conv2D)      (None, None, None,   55296       ['block_11_depthwise_relu[0][0]']
#                                 96)
#
#  block_11_project_BN (BatchNorm  (None, None, None,   384        ['block_11_project[0][0]']
#  alization)                     96)
#
#  block_11_add (Add)             (None, None, None,   0           ['block_10_project_BN[0][0]',
#                                 96)                               'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, None, None,   55296       ['block_11_add[0][0]']
#                                 576)
#
#  block_12_expand_BN (BatchNorma  (None, None, None,   2304       ['block_12_expand[0][0]']
#  lization)                      576)
#
#  block_12_expand_relu (ReLU)    (None, None, None,   0           ['block_12_expand_BN[0][0]']
#                                 576)
#
#  block_12_depthwise (DepthwiseC  (None, None, None,   5184       ['block_12_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_12_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_12_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_12_depthwise_relu (ReLU)  (None, None, None,   0          ['block_12_depthwise_BN[0][0]']
#                                 576)
#
#  block_12_project (Conv2D)      (None, None, None,   55296       ['block_12_depthwise_relu[0][0]']
#                                 96)
#
#  block_12_project_BN (BatchNorm  (None, None, None,   384        ['block_12_project[0][0]']
#  alization)                     96)
#
#  block_12_add (Add)             (None, None, None,   0           ['block_11_add[0][0]',
#                                 96)                               'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, None, None,   55296       ['block_12_add[0][0]']
#                                 576)
#
#  block_13_expand_BN (BatchNorma  (None, None, None,   2304       ['block_13_expand[0][0]']
#  lization)                      576)
#
#  block_13_expand_relu (ReLU)    (None, None, None,   0           ['block_13_expand_BN[0][0]']
#                                 576)
#
#  block_13_pad (ZeroPadding2D)   (None, None, None,   0           ['block_13_expand_relu[0][0]']
#                                 576)
#
#  block_13_depthwise (DepthwiseC  (None, None, None,   5184       ['block_13_pad[0][0]']
#  onv2D)                         576)
#
#  block_13_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_13_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_13_depthwise_relu (ReLU)  (None, None, None,   0          ['block_13_depthwise_BN[0][0]']
#                                 576)
#
#  block_13_project (Conv2D)      (None, None, None,   92160       ['block_13_depthwise_relu[0][0]']
#                                 160)
#
#  block_13_project_BN (BatchNorm  (None, None, None,   640        ['block_13_project[0][0]']
#  alization)                     160)
#
#  block_14_expand (Conv2D)       (None, None, None,   153600      ['block_13_project_BN[0][0]']
#                                 960)
#
#  block_14_expand_BN (BatchNorma  (None, None, None,   3840       ['block_14_expand[0][0]']
#  lization)                      960)
#
#  block_14_expand_relu (ReLU)    (None, None, None,   0           ['block_14_expand_BN[0][0]']
#                                 960)
#
#  block_14_depthwise (DepthwiseC  (None, None, None,   8640       ['block_14_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_14_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_14_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_14_depthwise_relu (ReLU)  (None, None, None,   0          ['block_14_depthwise_BN[0][0]']
#                                 960)
#
#  block_14_project (Conv2D)      (None, None, None,   153600      ['block_14_depthwise_relu[0][0]']
#                                 160)
#
#  block_14_project_BN (BatchNorm  (None, None, None,   640        ['block_14_project[0][0]']
#  alization)                     160)
#
#  block_14_add (Add)             (None, None, None,   0           ['block_13_project_BN[0][0]',
#                                 160)                              'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, None, None,   153600      ['block_14_add[0][0]']
#                                 960)
#
#  block_15_expand_BN (BatchNorma  (None, None, None,   3840       ['block_15_expand[0][0]']
#  lization)                      960)
#
#  block_15_expand_relu (ReLU)    (None, None, None,   0           ['block_15_expand_BN[0][0]']
#                                 960)
#
#  block_15_depthwise (DepthwiseC  (None, None, None,   8640       ['block_15_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_15_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_15_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_15_depthwise_relu (ReLU)  (None, None, None,   0          ['block_15_depthwise_BN[0][0]']
#                                 960)
#
#  block_15_project (Conv2D)      (None, None, None,   153600      ['block_15_depthwise_relu[0][0]']
#                                 160)
#
#  block_15_project_BN (BatchNorm  (None, None, None,   640        ['block_15_project[0][0]']
#  alization)                     160)
#
#  block_15_add (Add)             (None, None, None,   0           ['block_14_add[0][0]',
#                                 160)                              'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, None, None,   153600      ['block_15_add[0][0]']
#                                 960)
#
#  block_16_expand_BN (BatchNorma  (None, None, None,   3840       ['block_16_expand[0][0]']
#  lization)                      960)
#
#  block_16_expand_relu (ReLU)    (None, None, None,   0           ['block_16_expand_BN[0][0]']
#                                 960)
#
#  block_16_depthwise (DepthwiseC  (None, None, None,   8640       ['block_16_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_16_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_16_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_16_depthwise_relu (ReLU)  (None, None, None,   0          ['block_16_depthwise_BN[0][0]']
#                                 960)
#
#  block_16_project (Conv2D)      (None, None, None,   307200      ['block_16_depthwise_relu[0][0]']
#                                 320)
#
#  block_16_project_BN (BatchNorm  (None, None, None,   1280       ['block_16_project[0][0]']
#  alization)                     320)
#
#  Conv_1 (Conv2D)                (None, None, None,   409600      ['block_16_project_BN[0][0]']
#                                 1280)
#
#  Conv_1_bn (BatchNormalization)  (None, None, None,   5120       ['Conv_1[0][0]']
#                                 1280)
#
#  out_relu (ReLU)                (None, None, None,   0           ['Conv_1_bn[0][0]']
#                                 1280)
#
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %% [markdown]
# "Frozen" all weights pretrained models

# %%
pretrained_model.trainable = False

# %% [markdown]
# # Created main layers for end MobileNetV2 model

# %%
x = pretrained_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(class_num, activation='softmax')(x)
model = Model(inputs=pretrained_model.input, outputs=predictions)

# %% [markdown]
# View all model before training

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  Conv1 (Conv2D)                 (None, None, None,   864         ['input_1[0][0]']
#                                 32)
#
#  bn_Conv1 (BatchNormalization)  (None, None, None,   128         ['Conv1[0][0]']
#                                 32)
#
#  Conv1_relu (ReLU)              (None, None, None,   0           ['bn_Conv1[0][0]']
#                                 32)
#
#  expanded_conv_depthwise (Depth  (None, None, None,   288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    32)
#
#  expanded_conv_depthwise_BN (Ba  (None, None, None,   128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              32)
#
#  expanded_conv_depthwise_relu (  (None, None, None,   0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          32)                              ]']
#
#  expanded_conv_project (Conv2D)  (None, None, None,   512        ['expanded_conv_depthwise_relu[0]
#                                 16)                              [0]']
#
#  expanded_conv_project_BN (Batc  (None, None, None,   64         ['expanded_conv_project[0][0]']
#  hNormalization)                16)
#
#  block_1_expand (Conv2D)        (None, None, None,   1536        ['expanded_conv_project_BN[0][0]'
#                                 96)                              ]
#
#  block_1_expand_BN (BatchNormal  (None, None, None,   384        ['block_1_expand[0][0]']
#  ization)                       96)
#
#  block_1_expand_relu (ReLU)     (None, None, None,   0           ['block_1_expand_BN[0][0]']
#                                 96)
#
#  block_1_pad (ZeroPadding2D)    (None, None, None,   0           ['block_1_expand_relu[0][0]']
#                                 96)
#
#  block_1_depthwise (DepthwiseCo  (None, None, None,   864        ['block_1_pad[0][0]']
#  nv2D)                          96)
#
#  block_1_depthwise_BN (BatchNor  (None, None, None,   384        ['block_1_depthwise[0][0]']
#  malization)                    96)
#
#  block_1_depthwise_relu (ReLU)  (None, None, None,   0           ['block_1_depthwise_BN[0][0]']
#                                 96)
#
#  block_1_project (Conv2D)       (None, None, None,   2304        ['block_1_depthwise_relu[0][0]']
#                                 24)
#
#  block_1_project_BN (BatchNorma  (None, None, None,   96         ['block_1_project[0][0]']
#  lization)                      24)
#
#  block_2_expand (Conv2D)        (None, None, None,   3456        ['block_1_project_BN[0][0]']
#                                 144)
#
#  block_2_expand_BN (BatchNormal  (None, None, None,   576        ['block_2_expand[0][0]']
#  ization)                       144)
#
#  block_2_expand_relu (ReLU)     (None, None, None,   0           ['block_2_expand_BN[0][0]']
#                                 144)
#
#  block_2_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_2_expand_relu[0][0]']
#  nv2D)                          144)
#
#  block_2_depthwise_BN (BatchNor  (None, None, None,   576        ['block_2_depthwise[0][0]']
#  malization)                    144)
#
#  block_2_depthwise_relu (ReLU)  (None, None, None,   0           ['block_2_depthwise_BN[0][0]']
#                                 144)
#
#  block_2_project (Conv2D)       (None, None, None,   3456        ['block_2_depthwise_relu[0][0]']
#                                 24)
#
#  block_2_project_BN (BatchNorma  (None, None, None,   96         ['block_2_project[0][0]']
#  lization)                      24)
#
#  block_2_add (Add)              (None, None, None,   0           ['block_1_project_BN[0][0]',
#                                 24)                               'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, None, None,   3456        ['block_2_add[0][0]']
#                                 144)
#
#  block_3_expand_BN (BatchNormal  (None, None, None,   576        ['block_3_expand[0][0]']
#  ization)                       144)
#
#  block_3_expand_relu (ReLU)     (None, None, None,   0           ['block_3_expand_BN[0][0]']
#                                 144)
#
#  block_3_pad (ZeroPadding2D)    (None, None, None,   0           ['block_3_expand_relu[0][0]']
#                                 144)
#
#  block_3_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_3_pad[0][0]']
#  nv2D)                          144)
#
#  block_3_depthwise_BN (BatchNor  (None, None, None,   576        ['block_3_depthwise[0][0]']
#  malization)                    144)
#
#  block_3_depthwise_relu (ReLU)  (None, None, None,   0           ['block_3_depthwise_BN[0][0]']
#                                 144)
#
#  block_3_project (Conv2D)       (None, None, None,   4608        ['block_3_depthwise_relu[0][0]']
#                                 32)
#
#  block_3_project_BN (BatchNorma  (None, None, None,   128        ['block_3_project[0][0]']
#  lization)                      32)
#
#  block_4_expand (Conv2D)        (None, None, None,   6144        ['block_3_project_BN[0][0]']
#                                 192)
#
#  block_4_expand_BN (BatchNormal  (None, None, None,   768        ['block_4_expand[0][0]']
#  ization)                       192)
#
#  block_4_expand_relu (ReLU)     (None, None, None,   0           ['block_4_expand_BN[0][0]']
#                                 192)
#
#  block_4_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_4_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_4_depthwise_BN (BatchNor  (None, None, None,   768        ['block_4_depthwise[0][0]']
#  malization)                    192)
#
#  block_4_depthwise_relu (ReLU)  (None, None, None,   0           ['block_4_depthwise_BN[0][0]']
#                                 192)
#
#  block_4_project (Conv2D)       (None, None, None,   6144        ['block_4_depthwise_relu[0][0]']
#                                 32)
#
#  block_4_project_BN (BatchNorma  (None, None, None,   128        ['block_4_project[0][0]']
#  lization)                      32)
#
#  block_4_add (Add)              (None, None, None,   0           ['block_3_project_BN[0][0]',
#                                 32)                               'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, None, None,   6144        ['block_4_add[0][0]']
#                                 192)
#
#  block_5_expand_BN (BatchNormal  (None, None, None,   768        ['block_5_expand[0][0]']
#  ization)                       192)
#
#  block_5_expand_relu (ReLU)     (None, None, None,   0           ['block_5_expand_BN[0][0]']
#                                 192)
#
#  block_5_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_5_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_5_depthwise_BN (BatchNor  (None, None, None,   768        ['block_5_depthwise[0][0]']
#  malization)                    192)
#
#  block_5_depthwise_relu (ReLU)  (None, None, None,   0           ['block_5_depthwise_BN[0][0]']
#                                 192)
#
#  block_5_project (Conv2D)       (None, None, None,   6144        ['block_5_depthwise_relu[0][0]']
#                                 32)
#
#  block_5_project_BN (BatchNorma  (None, None, None,   128        ['block_5_project[0][0]']
#  lization)                      32)
#
#  block_5_add (Add)              (None, None, None,   0           ['block_4_add[0][0]',
#                                 32)                               'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, None, None,   6144        ['block_5_add[0][0]']
#                                 192)
#
#  block_6_expand_BN (BatchNormal  (None, None, None,   768        ['block_6_expand[0][0]']
#  ization)                       192)
#
#  block_6_expand_relu (ReLU)     (None, None, None,   0           ['block_6_expand_BN[0][0]']
#                                 192)
#
#  block_6_pad (ZeroPadding2D)    (None, None, None,   0           ['block_6_expand_relu[0][0]']
#                                 192)
#
#  block_6_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_6_pad[0][0]']
#  nv2D)                          192)
#
#  block_6_depthwise_BN (BatchNor  (None, None, None,   768        ['block_6_depthwise[0][0]']
#  malization)                    192)
#
#  block_6_depthwise_relu (ReLU)  (None, None, None,   0           ['block_6_depthwise_BN[0][0]']
#                                 192)
#
#  block_6_project (Conv2D)       (None, None, None,   12288       ['block_6_depthwise_relu[0][0]']
#                                 64)
#
#  block_6_project_BN (BatchNorma  (None, None, None,   256        ['block_6_project[0][0]']
#  lization)                      64)
#
#  block_7_expand (Conv2D)        (None, None, None,   24576       ['block_6_project_BN[0][0]']
#                                 384)
#
#  block_7_expand_BN (BatchNormal  (None, None, None,   1536       ['block_7_expand[0][0]']
#  ization)                       384)
#
#  block_7_expand_relu (ReLU)     (None, None, None,   0           ['block_7_expand_BN[0][0]']
#                                 384)
#
#  block_7_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_7_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_7_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_7_depthwise[0][0]']
#  malization)                    384)
#
#  block_7_depthwise_relu (ReLU)  (None, None, None,   0           ['block_7_depthwise_BN[0][0]']
#                                 384)
#
#  block_7_project (Conv2D)       (None, None, None,   24576       ['block_7_depthwise_relu[0][0]']
#                                 64)
#
#  block_7_project_BN (BatchNorma  (None, None, None,   256        ['block_7_project[0][0]']
#  lization)                      64)
#
#  block_7_add (Add)              (None, None, None,   0           ['block_6_project_BN[0][0]',
#                                 64)                               'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, None, None,   24576       ['block_7_add[0][0]']
#                                 384)
#
#  block_8_expand_BN (BatchNormal  (None, None, None,   1536       ['block_8_expand[0][0]']
#  ization)                       384)
#
#  block_8_expand_relu (ReLU)     (None, None, None,   0           ['block_8_expand_BN[0][0]']
#                                 384)
#
#  block_8_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_8_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_8_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_8_depthwise[0][0]']
#  malization)                    384)
#
#  block_8_depthwise_relu (ReLU)  (None, None, None,   0           ['block_8_depthwise_BN[0][0]']
#                                 384)
#
#  block_8_project (Conv2D)       (None, None, None,   24576       ['block_8_depthwise_relu[0][0]']
#                                 64)
#
#  block_8_project_BN (BatchNorma  (None, None, None,   256        ['block_8_project[0][0]']
#  lization)                      64)
#
#  block_8_add (Add)              (None, None, None,   0           ['block_7_add[0][0]',
#                                 64)                               'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, None, None,   24576       ['block_8_add[0][0]']
#                                 384)
#  block_9_expand_BN (BatchNormal  (None, None, None,   1536       ['block_9_expand[0][0]']
#  ization)                       384)
#
#  block_9_expand_relu (ReLU)     (None, None, None,   0           ['block_9_expand_BN[0][0]']
#                                 384)
#
#  block_9_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_9_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_9_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_9_depthwise[0][0]']
#  malization)                    384)
#
#  block_9_depthwise_relu (ReLU)  (None, None, None,   0           ['block_9_depthwise_BN[0][0]']
#                                 384)
#
#  block_9_project (Conv2D)       (None, None, None,   24576       ['block_9_depthwise_relu[0][0]']
#                                 64)
#
#  block_9_project_BN (BatchNorma  (None, None, None,   256        ['block_9_project[0][0]']
#  lization)                      64)
#
#  block_9_add (Add)              (None, None, None,   0           ['block_8_add[0][0]',
#                                 64)                               'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, None, None,   24576       ['block_9_add[0][0]']
#                                 384)
#
#  block_10_expand_BN (BatchNorma  (None, None, None,   1536       ['block_10_expand[0][0]']
#  lization)                      384)
#
#  block_10_expand_relu (ReLU)    (None, None, None,   0           ['block_10_expand_BN[0][0]']
#                                 384)
#
#  block_10_depthwise (DepthwiseC  (None, None, None,   3456       ['block_10_expand_relu[0][0]']
#  onv2D)                         384)
#
#  block_10_depthwise_BN (BatchNo  (None, None, None,   1536       ['block_10_depthwise[0][0]']
#  rmalization)                   384)
#
#  block_10_depthwise_relu (ReLU)  (None, None, None,   0          ['block_10_depthwise_BN[0][0]']
#                                 384)
#
#  block_10_project (Conv2D)      (None, None, None,   36864       ['block_10_depthwise_relu[0][0]']
#                                 96)
#
#  block_10_project_BN (BatchNorm  (None, None, None,   384        ['block_10_project[0][0]']
#  alization)                     96)
#
#  block_11_expand (Conv2D)       (None, None, None,   55296       ['block_10_project_BN[0][0]']
#                                 576)
#
#  block_11_expand_BN (BatchNorma  (None, None, None,   2304       ['block_11_expand[0][0]']
#  lization)                      576)
#
#  block_11_expand_relu (ReLU)    (None, None, None,   0           ['block_11_expand_BN[0][0]']
#                                 576)
#
#  block_11_depthwise (DepthwiseC  (None, None, None,   5184       ['block_11_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_11_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_11_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_11_depthwise_relu (ReLU)  (None, None, None,   0          ['block_11_depthwise_BN[0][0]']
#                                 576)
#
#  block_11_project (Conv2D)      (None, None, None,   55296       ['block_11_depthwise_relu[0][0]']
#                                 96)
#
#  block_11_project_BN (BatchNorm  (None, None, None,   384        ['block_11_project[0][0]']
#  alization)                     96)
#
#  block_11_add (Add)             (None, None, None,   0           ['block_10_project_BN[0][0]',
#                                 96)                               'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, None, None,   55296       ['block_11_add[0][0]']
#                                 576)
#
#  block_12_expand_BN (BatchNorma  (None, None, None,   2304       ['block_12_expand[0][0]']
#  lization)                      576)
#
#  block_12_expand_relu (ReLU)    (None, None, None,   0           ['block_12_expand_BN[0][0]']
#                                 576)
#
#  block_12_depthwise (DepthwiseC  (None, None, None,   5184       ['block_12_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_12_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_12_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_12_depthwise_relu (ReLU)  (None, None, None,   0          ['block_12_depthwise_BN[0][0]']
#                                 576)
#
#  block_12_project (Conv2D)      (None, None, None,   55296       ['block_12_depthwise_relu[0][0]']
#                                 96)
#
#  block_12_project_BN (BatchNorm  (None, None, None,   384        ['block_12_project[0][0]']
#  alization)                     96)
#
#  block_12_add (Add)             (None, None, None,   0           ['block_11_add[0][0]',
#                                 96)                               'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, None, None,   55296       ['block_12_add[0][0]']
#                                 576)
#
#  block_13_expand_BN (BatchNorma  (None, None, None,   2304       ['block_13_expand[0][0]']
#  lization)                      576)
#
#  block_13_expand_relu (ReLU)    (None, None, None,   0           ['block_13_expand_BN[0][0]']
#                                 576)
#
#  block_13_pad (ZeroPadding2D)   (None, None, None,   0           ['block_13_expand_relu[0][0]']
#                                 576)
#
#  block_13_depthwise (DepthwiseC  (None, None, None,   5184       ['block_13_pad[0][0]']
#  onv2D)                         576)
#
#  block_13_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_13_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_13_depthwise_relu (ReLU)  (None, None, None,   0          ['block_13_depthwise_BN[0][0]']
#                                 576)
#
#  block_13_project (Conv2D)      (None, None, None,   92160       ['block_13_depthwise_relu[0][0]']
#                                 160)
#
#  block_13_project_BN (BatchNorm  (None, None, None,   640        ['block_13_project[0][0]']
#  alization)                     160)
#
#  block_14_expand (Conv2D)       (None, None, None,   153600      ['block_13_project_BN[0][0]']
#                                 960)
#
#  block_14_expand_BN (BatchNorma  (None, None, None,   3840       ['block_14_expand[0][0]']
#  lization)                      960)
#
#  block_14_expand_relu (ReLU)    (None, None, None,   0           ['block_14_expand_BN[0][0]']
#                                 960)
#
#  block_14_depthwise (DepthwiseC  (None, None, None,   8640       ['block_14_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_14_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_14_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_14_depthwise_relu (ReLU)  (None, None, None,   0          ['block_14_depthwise_BN[0][0]']
#                                 960)
#
#  block_14_project (Conv2D)      (None, None, None,   153600      ['block_14_depthwise_relu[0][0]']
#                                 160)
#
#  block_14_project_BN (BatchNorm  (None, None, None,   640        ['block_14_project[0][0]']
#  alization)                     160)
#
#  block_14_add (Add)             (None, None, None,   0           ['block_13_project_BN[0][0]',
#                                 160)                              'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, None, None,   153600      ['block_14_add[0][0]']
#                                 960)
#
#  block_15_expand_BN (BatchNorma  (None, None, None,   3840       ['block_15_expand[0][0]']
#  lization)                      960)
#
#  block_15_expand_relu (ReLU)    (None, None, None,   0           ['block_15_expand_BN[0][0]']
#                                 960)
#
#  block_15_depthwise (DepthwiseC  (None, None, None,   8640       ['block_15_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_15_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_15_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_15_depthwise_relu (ReLU)  (None, None, None,   0          ['block_15_depthwise_BN[0][0]']
#                                 960)
#
#  block_15_project (Conv2D)      (None, None, None,   153600      ['block_15_depthwise_relu[0][0]']
#                                 160)
#
#  block_15_project_BN (BatchNorm  (None, None, None,   640        ['block_15_project[0][0]']
#  alization)                     160)
#
#  block_15_add (Add)             (None, None, None,   0           ['block_14_add[0][0]',
#                                 160)                              'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, None, None,   153600      ['block_15_add[0][0]']
#                                 960)
#
#  block_16_expand_BN (BatchNorma  (None, None, None,   3840       ['block_16_expand[0][0]']
#  lization)                      960)
#
#  block_16_expand_relu (ReLU)    (None, None, None,   0           ['block_16_expand_BN[0][0]']
#                                 960)
#
#  block_16_depthwise (DepthwiseC  (None, None, None,   8640       ['block_16_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_16_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_16_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_16_depthwise_relu (ReLU)  (None, None, None,   0          ['block_16_depthwise_BN[0][0]']
#                                 960)
#
#  block_16_project (Conv2D)      (None, None, None,   307200      ['block_16_depthwise_relu[0][0]']
#                                 320)
#
#  block_16_project_BN (BatchNorm  (None, None, None,   1280       ['block_16_project[0][0]']
#  alization)                     320)
#
#  Conv_1 (Conv2D)                (None, None, None,   409600      ['block_16_project_BN[0][0]']
#                                 1280)
#
#  Conv_1_bn (BatchNormalization)  (None, None, None,   5120       ['Conv_1[0][0]']
#                                 1280)
#
#  out_relu (ReLU)                (None, None, None,   0           ['Conv_1_bn[0][0]']
#                                 1280)
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['out_relu[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 512)          655872      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  batch_normalization (BatchNorm  (None, 512)         2048        ['dense[0][0]']
#  alization)
#
#  activation (Activation)        (None, 512)          0           ['batch_normalization[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['activation[0][0]']
#
#  dense_1 (Dense)                (None, 16)           8208        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 2,924,112
# Trainable params: 665,104
# Non-trainable params: 2,259,008
# __________________________________________________________________________________________________

# %% [markdown]
# # Train a composite neural network based on MobileNetV2 model

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=["accuracy"])

filepath="inceptionv3_mammals.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1,
                             save_best_only=True, mode='min')
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss',
                                            patience=10,
                                            verbose=1,
                                            factor=0.5,
                                            min_lr=0.00001)
callbacks_list = [checkpoint, learning_rate_reduction]

steps_per_epoch = 32
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    validation_data=test_generator,
    validation_steps=5,
    callbacks=callbacks_list,
    epochs=35,
    verbose=1)
# Out:
# Epoch 1/35
# 32/32 [==============================] - ETA: 0s - loss: 1.8678 - accuracy: 0.4570
# Epoch 1: val_loss improved from inf to 1.83644, saving model to inceptionv3_mammals.h5
# 32/32 [==============================] - 149s 5s/step - loss: 1.8678 - accuracy: 0.4570 - val_loss: 1.8364 - val_accuracy: 0.4062 - lr: 0.0010
# Epoch 2/35
# 32/32 [==============================] - ETA: 0s - loss: 1.4861 - accuracy: 0.5483
# Epoch 2: val_loss improved from 1.83644 to 1.37042, saving model to inceptionv3_mammals.h5
# 32/32 [==============================] - 143s 4s/step - loss: 1.4861 - accuracy: 0.5483 - val_loss: 1.3704 - val_accuracy: 0.5813 - lr: 0.0010
# Epoch 3/35
# 32/32 [==============================] - ETA: 0s - loss: 1.3533 - accuracy: 0.5771
# Epoch 3: val_loss improved from 1.37042 to 1.34895, saving model to inceptionv3_mammals.h5
# 32/32 [==============================] - 144s 4s/step - loss: 1.3533 - accuracy: 0.5771 - val_loss: 1.3490 - val_accuracy: 0.5938 - lr: 0.0010
# Epoch 4/35
# 32/32 [==============================] - ETA: 0s - loss: 1.2375 - accuracy: 0.6025
# Epoch 4: val_loss improved from 1.34895 to 1.19637, saving model to inceptionv3_mammals.h5
# 32/32 [==============================] - 138s 4s/step - loss: 1.2375 - accuracy: 0.6025 - val_loss: 1.1964 - val_accuracy: 0.5688 - lr: 0.0010
# Epoch 5/35
# 32/32 [==============================] - ETA: 0s - loss: 1.2129 - accuracy: 0.6167
# Epoch 5: val_loss improved from 1.19637 to 1.15679, saving model to inceptionv3_mammals.h5
# 32/32 [==============================] - 125s 4s/step - loss: 1.2129 - accuracy: 0.6167 - val_loss: 1.1568 - val_accuracy: 0.5906 - lr: 0.0010
# Epoch 6/35
# 32/32 [==============================] - ETA: 0s - loss: 1.1790 - accuracy: 0.6138
# Epoch 6: val_loss did not improve from 1.15679
# 32/32 [==============================] - 123s 4s/step - loss: 1.1790 - accuracy: 0.6138 - val_loss: 1.1643 - val_accuracy: 0.6031 - lr: 0.0010
# Epoch 7/35
# 32/32 [==============================] - ETA: 0s - loss: 1.1818 - accuracy: 0.6187
# Epoch 7: val_loss improved from 1.15679 to 0.90101, saving model to inceptionv3_mammals.h5
# 32/32 [==============================] - 119s 4s/step - loss: 1.1818 - accuracy: 0.6187 - val_loss: 0.9010 - val_accuracy: 0.7094 - lr: 0.0010
# Epoch 8/35
# 32/32 [==============================] - ETA: 0s - loss: 1.1179 - accuracy: 0.6265
# Epoch 8: val_loss did not improve from 0.90101
# 32/32 [==============================] - 113s 4s/step - loss: 1.1179 - accuracy: 0.6265 - val_loss: 0.9596 - val_accuracy: 0.6687 - lr: 0.0010
# Epoch 9/35
# 32/32 [==============================] - ETA: 0s - loss: 1.1030 - accuracy: 0.6421
# Epoch 9: val_loss did not improve from 0.90101
# 32/32 [==============================] - 112s 3s/step - loss: 1.1030 - accuracy: 0.6421 - val_loss: 1.0962 - val_accuracy: 0.6156 - lr: 0.0010
# Epoch 10/35
# 32/32 [==============================] - ETA: 0s - loss: 1.0662 - accuracy: 0.6489
# Epoch 10: val_loss did not improve from 0.90101
# 32/32 [==============================] - 109s 3s/step - loss: 1.0662 - accuracy: 0.6489 - val_loss: 0.9755 - val_accuracy: 0.6719 - lr: 0.0010
# Epoch 11/35
# 32/32 [==============================] - ETA: 0s - loss: 1.0617 - accuracy: 0.6509
# Epoch 11: val_loss did not improve from 0.90101
# 32/32 [==============================] - 107s 3s/step - loss: 1.0617 - accuracy: 0.6509 - val_loss: 1.0051 - val_accuracy: 0.6750 - lr: 0.0010
# Epoch 12/35
# 32/32 [==============================] - ETA: 0s - loss: 1.0109 - accuracy: 0.6636
# Epoch 12: val_loss did not improve from 0.90101
# 32/32 [==============================] - 105s 3s/step - loss: 1.0109 - accuracy: 0.6636 - val_loss: 0.9968 - val_accuracy: 0.6031 - lr: 0.0010
# Epoch 13/35
# 32/32 [==============================] - ETA: 0s - loss: 0.9908 - accuracy: 0.6753
# Epoch 13: val_loss improved from 0.90101 to 0.76192, saving model to inceptionv3_mammals.h5
# 32/32 [==============================] - 108s 3s/step - loss: 0.9908 - accuracy: 0.6753 - val_loss: 0.7619 - val_accuracy: 0.7563 - lr: 0.0010
# Epoch 14/35
# 32/32 [==============================] - ETA: 0s - loss: 0.9800 - accuracy: 0.6831
# Epoch 14: val_loss did not improve from 0.76192
# 32/32 [==============================] - 104s 3s/step - loss: 0.9800 - accuracy: 0.6831 - val_loss: 0.9686 - val_accuracy: 0.7031 - lr: 0.0010
# Epoch 15/35
# 32/32 [==============================] - ETA: 0s - loss: 1.0403 - accuracy: 0.6484
# Epoch 15: val_loss did not improve from 0.76192
# 32/32 [==============================] - 101s 3s/step - loss: 1.0403 - accuracy: 0.6484 - val_loss: 0.9909 - val_accuracy: 0.6750 - lr: 0.0010
# Epoch 16/35
# 32/32 [==============================] - ETA: 0s - loss: 0.9669 - accuracy: 0.6763
# Epoch 16: val_loss did not improve from 0.76192
# 32/32 [==============================] - 102s 3s/step - loss: 0.9669 - accuracy: 0.6763 - val_loss: 0.8853 - val_accuracy: 0.6938 - lr: 0.0010
# Epoch 17/35
# 32/32 [==============================] - ETA: 0s - loss: 0.9885 - accuracy: 0.6743
# Epoch 17: val_loss did not improve from 0.76192
# 32/32 [==============================] - 99s 3s/step - loss: 0.9885 - accuracy: 0.6743 - val_loss: 0.8980 - val_accuracy: 0.6969 - lr: 0.0010
# Epoch 18/35
# 32/32 [==============================] - ETA: 0s - loss: 0.9860 - accuracy: 0.6719
# Epoch 18: val_loss did not improve from 0.76192
# 32/32 [==============================] - 97s 3s/step - loss: 0.9860 - accuracy: 0.6719 - val_loss: 0.9071 - val_accuracy: 0.7031 - lr: 0.0010
# Epoch 19/35
# 32/32 [==============================] - ETA: 0s - loss: 0.9441 - accuracy: 0.6772
# Epoch 19: val_loss did not improve from 0.76192
# 32/32 [==============================] - 99s 3s/step - loss: 0.9441 - accuracy: 0.6772 - val_loss: 0.8449 - val_accuracy: 0.6938 - lr: 0.0010
# Epoch 20/35
# 32/32 [==============================] - ETA: 0s - loss: 1.0094 - accuracy: 0.6631
# Epoch 20: val_loss did not improve from 0.76192
# 32/32 [==============================] - 97s 3s/step - loss: 1.0094 - accuracy: 0.6631 - val_loss: 0.8131 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 21/35
# 32/32 [==============================] - ETA: 0s - loss: 0.9007 - accuracy: 0.7124
# Epoch 21: val_loss did not improve from 0.76192
# 32/32 [==============================] - 97s 3s/step - loss: 0.9007 - accuracy: 0.7124 - val_loss: 0.9517 - val_accuracy: 0.6906 - lr: 0.0010
# Epoch 22/35
# 32/32 [==============================] - ETA: 0s - loss: 0.9467 - accuracy: 0.6802
# Epoch 22: val_loss did not improve from 0.76192
# 32/32 [==============================] - 96s 3s/step - loss: 0.9467 - accuracy: 0.6802 - val_loss: 0.8973 - val_accuracy: 0.6969 - lr: 0.0010
# Epoch 23/35
# 32/32 [==============================] - ETA: 0s - loss: 0.9212 - accuracy: 0.6802
# Epoch 23: val_loss did not improve from 0.76192
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 32/32 [==============================] - 97s 3s/step - loss: 0.9212 - accuracy: 0.6802 - val_loss: 0.9722 - val_accuracy: 0.6531 - lr: 0.0010
# Epoch 24/35
# 32/32 [==============================] - ETA: 0s - loss: 0.8999 - accuracy: 0.6890
# Epoch 24: val_loss did not improve from 0.76192
# 32/32 [==============================] - 94s 3s/step - loss: 0.8999 - accuracy: 0.6890 - val_loss: 0.8033 - val_accuracy: 0.7125 - lr: 5.0000e-04
# Epoch 25/35
# 32/32 [==============================] - ETA: 0s - loss: 0.8814 - accuracy: 0.7075
# Epoch 25: val_loss did not improve from 0.76192
# 32/32 [==============================] - 93s 3s/step - loss: 0.8814 - accuracy: 0.7075 - val_loss: 0.8643 - val_accuracy: 0.7000 - lr: 5.0000e-04
# Epoch 26/35
# 32/32 [==============================] - ETA: 0s - loss: 0.9205 - accuracy: 0.6880
# Epoch 26: val_loss did not improve from 0.76192
# 32/32 [==============================] - 94s 3s/step - loss: 0.9205 - accuracy: 0.6880 - val_loss: 0.8115 - val_accuracy: 0.7156 - lr: 5.0000e-04
# Epoch 27/35
# 32/32 [==============================] - ETA: 0s - loss: 0.8626 - accuracy: 0.7188
# Epoch 27: val_loss did not improve from 0.76192
# 32/32 [==============================] - 94s 3s/step - loss: 0.8626 - accuracy: 0.7188 - val_loss: 0.8937 - val_accuracy: 0.7188 - lr: 5.0000e-04
# Epoch 28/35
# 32/32 [==============================] - ETA: 0s - loss: 0.8928 - accuracy: 0.7041
# Epoch 28: val_loss did not improve from 0.76192
# 32/32 [==============================] - 92s 3s/step - loss: 0.8928 - accuracy: 0.7041 - val_loss: 0.8605 - val_accuracy: 0.6938 - lr: 5.0000e-04
# Epoch 29/35
# 32/32 [==============================] - ETA: 0s - loss: 0.8399 - accuracy: 0.7124
# Epoch 29: val_loss did not improve from 0.76192
# 32/32 [==============================] - 94s 3s/step - loss: 0.8399 - accuracy: 0.7124 - val_loss: 0.8601 - val_accuracy: 0.7063 - lr: 5.0000e-04
# Epoch 30/35
# 32/32 [==============================] - ETA: 0s - loss: 0.8434 - accuracy: 0.7148
# Epoch 30: val_loss did not improve from 0.76192
# 32/32 [==============================] - 91s 3s/step - loss: 0.8434 - accuracy: 0.7148 - val_loss: 0.7781 - val_accuracy: 0.7500 - lr: 5.0000e-04
# Epoch 31/35
# 32/32 [==============================] - ETA: 0s - loss: 0.8470 - accuracy: 0.7153
# Epoch 31: val_loss did not improve from 0.76192
# 32/32 [==============================] - 90s 3s/step - loss: 0.8470 - accuracy: 0.7153 - val_loss: 0.8255 - val_accuracy: 0.7188 - lr: 5.0000e-04
# Epoch 32/35
# 32/32 [==============================] - ETA: 0s - loss: 0.8315 - accuracy: 0.7212
# Epoch 32: val_loss did not improve from 0.76192
# 32/32 [==============================] - 91s 3s/step - loss: 0.8315 - accuracy: 0.7212 - val_loss: 0.7775 - val_accuracy: 0.7281 - lr: 5.0000e-04
# Epoch 33/35
# 32/32 [==============================] - ETA: 0s - loss: 0.8681 - accuracy: 0.7202
# Epoch 33: val_loss did not improve from 0.76192
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 32/32 [==============================] - 95s 3s/step - loss: 0.8681 - accuracy: 0.7202 - val_loss: 0.8340 - val_accuracy: 0.7094 - lr: 5.0000e-04
# Epoch 34/35
# 32/32 [==============================] - ETA: 0s - loss: 0.8504 - accuracy: 0.7183
# Epoch 34: val_loss did not improve from 0.76192
# 32/32 [==============================] - 89s 3s/step - loss: 0.8504 - accuracy: 0.7183 - val_loss: 0.7978 - val_accuracy: 0.7344 - lr: 2.5000e-04
# Epoch 35/35
# 32/32 [==============================] - ETA: 0s - loss: 0.8840 - accuracy: 0.6904
# Epoch 35: val_loss improved from 0.76192 to 0.72836, saving model to inceptionv3_mammals.h5
# 32/32 [==============================] - 92s 3s/step - loss: 0.8840 - accuracy: 0.6904 - val_loss: 0.7284 - val_accuracy: 0.7625 - lr: 2.5000e-04

# %%
test_score = model.evaluate_generator(testing_generator, batch_size)

print("[INFO] accuracy: {:.2f}%".format(test_score[1] * 100))
print("[INFO] Loss: ",test_score[0])
# Out:
# [INFO] accuracy: 73.07%
# [INFO] Loss:  0.8039919137954712

# %%
#Plot the Graph

# Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)

# Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
Y_pred = model.predict_generator(testing_generator)
y_pred = np.argmax(Y_pred, axis=1)
cm = confusion_matrix(testing_generator.classes, y_pred)
class_counts = np.bincount(testing_generator.classes)
sorted_indices = np.argsort(class_counts)[::-1]
sorted_classes = [classes[i] for i in sorted_indices]
sorted_cm = cm[:, sorted_indices][sorted_indices, :]
group_counts = ["{0:0.0f}".format(value) for value in sorted_cm.flatten()]
group_percentage = (sorted_cm.T / sorted_cm.sum(axis=1)).T
group_percentages = ["{0:.1%}".format(value) for value in group_percentage.flatten()]
labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_counts, group_percentages)]
labels = np.asarray(labels).reshape(class_num, class_num)

# %%
plt.figure(figsize=(25, 25))
heatmap = sns.heatmap(group_percentage, annot=labels, fmt='', cmap='Blues', xticklabels=sorted_classes, yticklabels=sorted_classes,annot_kws={"size": 20})
heatmap.set_yticklabels(heatmap.get_yticklabels(), size = 20, rotation=0)
heatmap.set_xticklabels(heatmap.get_yticklabels(), size = 20, rotation=90)

plt.show()

# %%
print('Classification Report')
print(classification_report(testing_generator.classes, y_pred, target_names=classes))
# Out:
# Classification Report
#                         precision    recall  f1-score   support
#
#          American Mink       0.81      0.74      0.77        65
#              Brown Rat       0.00      0.00      0.00         1
#       Eastern Chipmunk       0.88      0.68      0.76        31
#     Eastern Cottontail       0.73      0.84      0.78       490
#     Long-tailed Weasel       0.72      0.74      0.73       350
#           Masked Shrew       0.55      0.51      0.53       637
#   Meadow Jumping Mouse       0.70      0.29      0.41        24
#            Meadow Vole       0.85      0.81      0.83      2127
#  N. Short-tailed Shrew       0.80      0.29      0.43       113
#                Raccoon       0.43      0.30      0.35        10
#        Star-nosed mole       0.00      0.00      0.00        17
#          Striped Skunk       1.00      0.12      0.22        16
#       Virginia Opossum       0.66      0.76      0.71       149
#     White-footed Mouse       0.71      0.87      0.78      1583
#              Woodchuck       0.00      0.00      0.00         7
# Woodland Jumping Mouse       0.57      0.17      0.26       227
#
#               accuracy                           0.74      5847
#              macro avg       0.59      0.44      0.47      5847
#           weighted avg       0.74      0.74      0.73      5847

# %% [markdown]
# # Distribution of human review vs error

# %%
y_true = testing_generator.classes
cm = confusion_matrix(testing_generator.classes, y_pred)
class_counts = np.bincount(y_true)
sorted_indices = np.argsort(class_counts)[::-1]
sorted_classes = [classes[i] for i in sorted_indices]
sorted_cm = cm[:, sorted_indices][sorted_indices, :]

group_counts = ["{0:0.0f}".format(value) for value in sorted_cm.flatten()]
group_percentage = (sorted_cm.T / sorted_cm.sum(axis=1)).T

buckets = [(i / 10.0, (i + 1) / 10.0) for i in range(10)]  # [(0.0, 0.1), (0.1, 0.2), ..., (0.8, 0.9), (0.9, 1.0)]

correct_bucket_counts = {f'{bucket[0]}': 0 for bucket in buckets}
incorrect_bucket_counts = {f'{bucket[0]}': 0 for bucket in buckets}

for i in range(len(y_true)):
    true_label = y_true[i]
    predicted_label = np.argmax(Y_pred[i])
    max_probability = Y_pred[i][predicted_label]
    
    for bucket in buckets:
        if bucket[0] <= max_probability < bucket[1]:
            if true_label == predicted_label:
                correct_bucket_counts[f'{bucket[0]}'] += 1
            else:
                incorrect_bucket_counts[f'{bucket[0]}'] += 1
            break

total_correct = sum(correct_bucket_counts.values())
total_incorrect = sum(incorrect_bucket_counts.values())
total_images = total_correct + total_incorrect

correct_bucket_probabilities = {key: value / total_correct for key, value in correct_bucket_counts.items()}
incorrect_bucket_probabilities = {key: value / total_incorrect for key, value in incorrect_bucket_counts.items()}

thresholds = np.arange(0.9, 0.0, -0.1).round(1)   # Starting from 0.9 and going down to 0.1 in increments of 0.1
human_bucket_probabilities = []
error = []

for threshold_value in thresholds:
    sum_counts_below_threshold = sum(correct_bucket_counts[key] + incorrect_bucket_counts[key] for key in correct_bucket_counts.keys() if float(key) < threshold_value)
    human_bucket_probability = (sum_counts_below_threshold / total_images) * 100
    human_bucket_probabilities.append(human_bucket_probability)
    error_rate = (sum(incorrect_bucket_counts[key] for key in correct_bucket_counts.keys() if float(key) >= threshold_value))/total_images
    error.append(error_rate*100)

plt.figure(figsize=(10, 5))

plt.plot(thresholds, human_bucket_probabilities, marker='o', linestyle='-', linewidth=2, color='black', label='Human Review')
plt.plot(thresholds, error, marker='s', linestyle='--',linewidth=2, color='red', label='Error Rate')

plt.xlabel('Threshold')
plt.ylabel('Percentage')
plt.title('Human Review and Error Rate vs. Threshold - Class level')
plt.legend()
plt.grid(True)
plt.show()

# %%
buckets = [(i / 10.0, (i + 1) / 10.0) for i in range(10)]  # [(0.0, 0.1), (0.1, 0.2), ..., (0.8, 0.9), (0.9, 1.0)]
class_colors = sns.color_palette("husl", n_colors=len(sorted_classes))
combined_human_probabilities = []
combined_error_rates = []
for i, label_class in enumerate(range(len(sorted_classes))):
    correct_bucket_counts = {f'{bucket[0]}': 0 for bucket in buckets}
    incorrect_bucket_counts = {f'{bucket[0]}': 0 for bucket in buckets}

    for j in range(len(y_true)):
        true_label = y_true[j]
        predicted_label = np.argmax(Y_pred[j])
        max_probability = Y_pred[j][predicted_label]
        if true_label == label_class:
            for bucket in buckets:
                if bucket[0] <= max_probability < bucket[1]:
                    if true_label == predicted_label:
                        correct_bucket_counts[f'{bucket[0]}'] += 1
                    else:
                        incorrect_bucket_counts[f'{bucket[0]}'] += 1
                    break

    total_correct = sum(correct_bucket_counts.values())
    total_incorrect = sum(incorrect_bucket_counts.values())
    total_images = total_correct + total_incorrect
    correct_bucket_probabilities = {key: value / total_correct if total_correct != 0 else 0 for key, value in correct_bucket_counts.items()}
    incorrect_bucket_probabilities = {key: value / total_incorrect if total_incorrect != 0 else 0 for key, value in incorrect_bucket_counts.items()}
    thresholds = np.arange(0.9, 0.0, -0.1).round(1)   # Starting from 0.9 and going down to 0.1 in increments of 0.1
    human_bucket_probabilities = []
    error = []

    for threshold_value in thresholds:
        sum_counts_below_threshold = sum(correct_bucket_counts[key] + incorrect_bucket_counts[key] for key in correct_bucket_counts.keys() if float(key) < threshold_value)
        human_bucket_probability = (sum_counts_below_threshold / total_images) * 100
        human_bucket_probabilities.append(human_bucket_probability)
        error_rate = (sum(incorrect_bucket_counts[key] for key in correct_bucket_counts.keys() if float(key) >= threshold_value))/total_images
        error.append(error_rate*100)

    plt.figure(figsize=(10, 5))
    plt.plot(thresholds, human_bucket_probabilities, marker='o', linestyle='-', color=class_colors[i], label='Human Review')
    plt.plot(thresholds, error, marker='s', linestyle='--', color=class_colors[i], label='Error Rate')
    plt.xlabel('Threshold')
    plt.ylabel(f'Percentage')
    plt.tick_params(axis='y')
    plt.legend(loc='upper left')
    plt.title(f'Human Review and Error Rate vs. Threshold - {classes[label_class]}')
    plt.grid(True)
    plt.show()

# %%
buckets = [(i / 10.0, (i + 1) / 10.0) for i in range(10)]  # [(0.0, 0.1), (0.1, 0.2), ..., (0.8, 0.9), (0.9, 1.0)]

# Classify probabilities into buckets for both correct and incorrect predictions
correct_bucket_counts = {f'{bucket[0]}-{bucket[1]}': 0 for bucket in buckets}
incorrect_bucket_counts = {f'{bucket[0]}-{bucket[1]}': 0 for bucket in buckets}

for i in range(len(y_true)):
    true_label = y_true[i]
    predicted_label = np.argmax(Y_pred[i])
    max_probability = Y_pred[i][predicted_label]
    
    # Determine the probability bucket for the prediction
    for bucket in buckets:
        if bucket[0] <= max_probability < bucket[1]:
            if true_label == predicted_label:
                correct_bucket_counts[f'{bucket[0]}-{bucket[1]}'] += 1
            else:
                incorrect_bucket_counts[f'{bucket[0]}-{bucket[1]}'] += 1
            break

# Calculate the probability distribution of correct and incorrect predictions
total_correct = sum(correct_bucket_counts.values())
total_incorrect = sum(incorrect_bucket_counts.values())

correct_bucket_probabilities = {key: value / total_correct for key, value in correct_bucket_counts.items()}
incorrect_bucket_probabilities = {key: value / total_incorrect for key, value in incorrect_bucket_counts.items()}

# Visualize the results

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.barplot(x=list(correct_bucket_probabilities.keys()), y=list(correct_bucket_probabilities.values()))
plt.title('Probability Distribution of Correct Predictions')

plt.subplot(1, 2, 2)
sns.barplot(x=list(incorrect_bucket_probabilities.keys()), y=list(incorrect_bucket_probabilities.values()))
plt.title('Probability Distribution of Incorrect Predictions')

plt.show()
